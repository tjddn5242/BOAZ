# %% [markdown]
# # Used car

# %%
# !pip install kaggle
from google.colab import files
files.upload()
# Out:
# ...
#      <input type="file" id="files-bed457d4-2350-411b-adae-b5482d064c09" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bed457d4-2350-411b-adae-b5482d064c09">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"startingdataanalysis","key":"612e4754250bb25f880ea0b9e7d67c5b"}'}

# %%
ls -1ha kaggle.json
# Out:
# kaggle.json

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# Permission Warning 이 일어나지 않도록 
# !chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets download -d adityadesai13/used-car-dataset-ford-and-mercedes
# Out:
# ...
#   0% 0.00/1.10M [00:00<?, ?B/s]
# 100% 1.10M/1.10M [00:00<00:00, 76.5MB/s]

# %%
! ls
# Out:
# kaggle.json  sample_data  used-car-dataset-ford-and-mercedes.zip

# %%
! unzip used-car-dataset-ford-and-mercedes.zip
# Out:
# Archive:  used-car-dataset-ford-and-mercedes.zip
#   inflating: audi.csv
#   inflating: bmw.csv
#   inflating: cclass.csv
#   inflating: focus.csv
#   inflating: ford.csv
#   inflating: hyundi.csv
#   inflating: merc.csv
#   inflating: skoda.csv
#   inflating: toyota.csv
#   inflating: unclean cclass.csv
#   inflating: unclean focus.csv
#   inflating: vauxhall.csv
#   inflating: vw.csv

# %%
import pandas as pd

# %%
audi = pd.read_csv('./audi.csv')
bmw = pd.read_csv('./bmw.csv')
cclass = pd.read_csv('./cclass.csv')
focus = pd.read_csv('./focus.csv')
ford = pd.read_csv('./ford.csv')
hyundi = pd.read_csv('./hyundi.csv')
merc = pd.read_csv('./merc.csv')
skoda = pd.read_csv('./skoda.csv')
toyota = pd.read_csv('./toyota.csv')
unclean_cclass = pd.read_csv('./unclean cclass.csv')
unclean_focus = pd.read_csv('./unclean focus.csv')
vauxhall = pd.read_csv('./vauxhall.csv')
vw = pd.read_csv('./vw.csv')
data_list = [audi, bmw, cclass, focus, ford, hyundi, merc, skoda, toyota, unclean_cclass, unclean_focus, vauxhall, vw]

# %%
ford.year.unique()
# Out:
# array([2017, 2018, 2019, 2015, 2014, 2016, 2013, 2020, 2012, 2008, 2010,
#        2009, 2011, 1998, 2007, 2005, 2006, 2002, 2003, 1996, 2004, 2000,
#        2060])

# %%
for data in data_list:
    print('='*80)
    print(f'{data.columns}\n')
    print(f'{data.shape}\n')
# Out:
# ...
# Index(['model', 'year', 'price', 'transmission', 'mileage', 'fuelType', 'tax',
#        'mpg', 'engineSize'],
#       dtype='object')
#
# (10668, 9)
#
# ...
# Index(['model', 'year', 'price', 'transmission', 'mileage', 'fuelType', 'tax',
#        'mpg', 'engineSize'],
#       dtype='object')
#
# (10781, 9)
#
# ...
# Index(['model', 'year', 'price', 'transmission', 'mileage', 'fuelType',
#        'engineSize'],
#       dtype='object')
#
# (3899, 7)
#
# ...
# Index(['model', 'year', 'price', 'transmission', 'mileage', 'fuelType',
#        'engineSize'],
#       dtype='object')
#
# (5454, 7)
#
# ...
# Index(['model', 'year', 'price', 'transmission', 'mileage', 'fuelType', 'tax',
#        'mpg', 'engineSize'],
#       dtype='object')
#
# (17965, 9)
#
# ...
# Index(['model', 'year', 'price', 'transmission', 'mileage', 'fuelType',
#        'tax(£)', 'mpg', 'engineSize'],
#       dtype='object')
#
# (4860, 9)
#
# ...
# Index(['model', 'year', 'price', 'transmission', 'mileage', 'fuelType', 'tax',
# ...

# %% [markdown]
# # Car rantal

# %%
! kaggle datasets download -d kushleshkumar/cornell-car-rental-dataset
# Out:
# cornell-car-rental-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !unzip cornell-car-rental-dataset.zip
# Out:
# Archive:  cornell-car-rental-dataset.zip
#   inflating: CarRentalData.csv
#   inflating: CarRentalDataV1.csv

# %%
rental_data = pd.read_csv('./CarRentalDataV1.csv')
rental_data
# Out:
#       fuelType  rating  ...  vehicle.year  airportcity
# 0     ELECTRIC    5.00  ...        2019.0  Albuquerque
# 1     ELECTRIC    5.00  ...        2018.0  Albuquerque
# 2       HYBRID    4.92  ...        2012.0  Albuquerque
# 3     GASOLINE    5.00  ...        2018.0  Albuquerque
# 4     GASOLINE    5.00  ...        2010.0  Albuquerque
# ...        ...     ...  ...           ...          ...
# 5846  GASOLINE    5.00  ...        2017.0     Honolulu
# 5847    HYBRID    5.00  ...        2010.0     Honolulu
# 5848  GASOLINE    4.94  ...        2013.0     Honolulu
# 5849  GASOLINE     NaN  ...        2015.0     Honolulu
# 5850  GASOLINE    5.00  ...        2013.0     Honolulu
#
# [5851 rows x 16 columns]

# %%
rental_data['airportcity'].nunique()
# Out:
# 103

# %%
rental_data.shape
# Out:
# (5851, 16)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
plt.hist(rental_data['rate.daily'].values)
plt.show()

# %%
rental_data['rate.daily'].values.shape
# Out:
# (5851,)

# %%
len(rental_data)
# Out:
# 5851

# %% [markdown]
# # Google Mobility

# %%
import pandas as pd

# %%
# !ls
# Out:
# Global_Mobility_Report.csv  sample_data

# %%
mobility = pd.read_csv('./Global_Mobility_Report.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
mobility
# Out:
#        country_region_code  ... residential_percent_change_from_baseline
# 0                       AE  ...                                      1.0
# 1                       AE  ...                                      1.0
# 2                       AE  ...                                      1.0
# 3                       AE  ...                                      1.0
# 4                       AE  ...                                      1.0
# ...                    ...  ...                                      ...
# 205879                  AR  ...                                     -3.0
# 205880                  AR  ...                                      0.0
# 205881                  AR  ...                                      1.0
# 205882                  AR  ...                                      2.0
# 205883                  AR  ...                                      NaN
#
# [205884 rows x 15 columns]

# %%
mobility.date.nunique()
# Out:
# 718

# %%
len(mobility[mobility['country_region']=='Kabul Metropolitan Area'])
# Out:
# 673

# %% [markdown]
# # Google Mobility 2

# %%
cd ./drive/MyDrive/Region_Mobility_Report_CSVs/
# Out:
# /content/drive/MyDrive/Region_Mobility_Report_CSVs

# %%
# !ls
# Out:
# 2020_AE_Region_Mobility_Report.csv  2021_LA_Region_Mobility_Report.csv
# 2020_AF_Region_Mobility_Report.csv  2021_LB_Region_Mobility_Report.csv
# 2020_AG_Region_Mobility_Report.csv  2021_LI_Region_Mobility_Report.csv
# 2020_AO_Region_Mobility_Report.csv  2021_LK_Region_Mobility_Report.csv
# 2020_AR_Region_Mobility_Report.csv  2021_LT_Region_Mobility_Report.csv
# 2020_AT_Region_Mobility_Report.csv  2021_LU_Region_Mobility_Report.csv
# 2020_AU_Region_Mobility_Report.csv  2021_LV_Region_Mobility_Report.csv
# 2020_AW_Region_Mobility_Report.csv  2021_LY_Region_Mobility_Report.csv
# 2020_BA_Region_Mobility_Report.csv  2021_MA_Region_Mobility_Report.csv
# 2020_BB_Region_Mobility_Report.csv  2021_MD_Region_Mobility_Report.csv
# 2020_BD_Region_Mobility_Report.csv  2021_MK_Region_Mobility_Report.csv
# 2020_BE_Region_Mobility_Report.csv  2021_ML_Region_Mobility_Report.csv
# 2020_BF_Region_Mobility_Report.csv  2021_MM_Region_Mobility_Report.csv
# ...

# %%
import os

# %%
file_list = os.listdir('./')

# %%
type(file_list[0])
# Out:
# str

# %%
len(file_list)
# Out:
# 405

# %%
print('./'+file_list[1])
# Out:
# ./2020_AW_Region_Mobility_Report.csv

# %%
import pandas as pd

# %%
data = dict()
for i in file_list:
    data[i]=pd.read_csv('./'+i)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data.keys()
# Out:
# dict_keys(['2020_AR_Region_Mobility_Report.csv', '2020_AW_Region_Mobility_Report.csv', '2020_AE_Region_Mobility_Report.csv', '2020_AU_Region_Mobility_Report.csv', '2020_AT_Region_Mobility_Report.csv', '2020_AF_Region_Mobility_Report.csv', '2020_AG_Region_Mobility_Report.csv', '2020_AO_Region_Mobility_Report.csv', '2020_BA_Region_Mobility_Report.csv', '2020_BD_Region_Mobility_Report.csv', '2020_BJ_Region_Mobility_Report.csv', '2020_BB_Region_Mobility_Report.csv', '2020_BF_Region_Mobility_Report.csv', '2020_BE_Region_Mobility_Report.csv', '2020_BO_Region_Mobility_Report.csv', '2020_BH_Region_Mobility_Report.csv', '2020_BG_Region_Mobility_Report.csv', '2020_CH_Region_Mobility_Report.csv', '2020_CL_Region_Mobility_Report.csv', '2020_BR_Region_Mobility_Report.csv', '2020_BZ_Region_Mobility_Report.csv', '2020_BS_Region_Mobility_Report.csv', '2020_BW_Region_Mobility_Report.csv', '2020_CA_Region_Mobility_Report.csv', '2020_CI_Region_Mobility_Report.csv', '2020_BY_Region_Mobility_Report.csv',
# ...

# %%
for i in data.keys():
    print(f'{i[5:7]}:{len(data[i])}')
# Out:
# AR:130441
# AW:321
# AE:2561
# AU:85330
# AT:30403
# AF:552
# AG:1292
# AO:1528
# BA:321
# BD:321
# BJ:1650
# BB:2357
# BF:1399
# BE:4494
# BO:15587
# BH:321
# BG:35899
# CH:8374
# CL:22423
# BR:590689
# BZ:1718
# BS:1234
# BW:2388
# CA:77330
# CI:3697
# BY:321
# DK:30004
# CZ:28934
# EE:3991
# CV:1207
# DE:5457
# CM:7845
# CO:100619
# EC:40737
# EG:9561
# DO:9298
# CR:321
# ES:20210
# GH:963
# HR:6934
# GB:133382
# FI:24817
# HN:16460
# GA:1148
# GW:296
# GT:33832
# FJ:321
# GR:2568
# HK:321
# FR:35299
# GE:552
# IE:8515
# ID:11235
# HT:2826
# JP:15408
# IN:212855
# IL:6417
# KE:12313
# JO:4291
# JM:4591
# HU:6733
# KG:2493
# IQ:321
# IT:40764
# MD:321
# KR:642
# LY:2953
# LB:9500
# KH:6392
# LU:321
# ML:642
# LI:296
# MK:321
# KZ:321
# LK:321
# MA:1284
# LV:9706
# LA:321
# LT:18933
# KW:2568
# NP:321
# MZ:6691
# MX:10593
# MN:684
# MT:321
# MY:5452
# NG:60816
# MM:963
# NE:1960
# NA:2367
# NI:5299
# NZ:5336
# MU:3390
# NO:40783
# NL:110241
# PK:6691
# PE:41370
# OM:3700
# RE:754
# ...

# %%
US2021 = data['2021_US_Region_Mobility_Report.csv']

# %%
US2021
# Out:
#        country_region_code  ... residential_percent_change_from_baseline
# 0                       US  ...                                     27.0
# 1                       US  ...                                      9.0
# 2                       US  ...                                      7.0
# 3                       US  ...                                     12.0
# 4                       US  ...                                     12.0
# ...                    ...  ...                                      ...
# 951955                  US  ...                                      NaN
# 951956                  US  ...                                      NaN
# 951957                  US  ...                                      NaN
# 951958                  US  ...                                      NaN
# 951959                  US  ...                                      NaN
#
# [951960 rows x 15 columns]

# %%
US2021.columns
# Out:
# Index(['country_region_code', 'country_region', 'sub_region_1', 'sub_region_2',
#        'metro_area', 'iso_3166_2_code', 'census_fips_code', 'place_id', 'date',
#        'retail_and_recreation_percent_change_from_baseline',
#        'grocery_and_pharmacy_percent_change_from_baseline',
#        'parks_percent_change_from_baseline',
#        'transit_stations_percent_change_from_baseline',
#        'workplaces_percent_change_from_baseline',
#        'residential_percent_change_from_baseline'],
#       dtype='object')

# %%
US2021.shape
# Out:
# (951960, 15)

# %%
US2021.metro_area.unique()
# Out:
# array([nan])

# %%
US2021.isnull().sum()
# Out:
# country_region_code                                        0
# country_region                                             0
# sub_region_1                                             365
# sub_region_2                                           18980
# metro_area                                            951960
# iso_3166_2_code                                       933345
# census_fips_code                                       34257
# place_id                                                   0
# date                                                       0
# retail_and_recreation_percent_change_from_baseline    344101
# grocery_and_pharmacy_percent_change_from_baseline     411037
# parks_percent_change_from_baseline                    710323
# transit_stations_percent_change_from_baseline         587009
# workplaces_percent_change_from_baseline                10538
# residential_percent_change_from_baseline              361361
# dtype: int64
