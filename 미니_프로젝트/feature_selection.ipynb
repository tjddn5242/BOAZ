# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd ./drive/MyDrive/미니_프로젝트/data
# Out:
# /content/drive/MyDrive/미니_프로젝트/data

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.7/dist-packages (0.90)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from xgboost) (1.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from xgboost) (1.21.5)

# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-2.10.0-py3-none-any.whl (308 kB)
#      |████████████████████████████████| 308 kB 4.3 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (21.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from optuna) (3.13)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from optuna) (1.21.5)
# Collecting alembic
#   Downloading alembic-1.7.6-py3-none-any.whl (210 kB)
#      |████████████████████████████████| 210 kB 43.9 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from optuna) (4.62.3)
# Requirement already satisfied: sqlalchemy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (1.4.31)
# Collecting cliff
#   Downloading cliff-3.10.1-py3-none-any.whl (81 kB)
#      |████████████████████████████████| 81 kB 8.2 MB/s
# Requirement already satisfied: scipy!=1.4.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (1.4.1)
# Collecting cmaes>=0.8.2
#   Downloading cmaes-0.8.2-py3-none-any.whl (15 kB)
# Collecting colorlog
#   Downloading colorlog-6.6.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->optuna) (3.0.7)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.1.0->optuna) (4.11.1)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.1.0->optuna) (1.1.2)
# Collecting Mako
#   Downloading Mako-1.1.6-py2.py3-none-any.whl (75 kB)
#      |████████████████████████████████| 75 kB 4.2 MB/s
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from alembic->optuna) (5.4.0)
# Requirement already satisfied: PrettyTable>=0.7.2 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (3.1.1)
# Collecting autopage>=0.4.0
#   Downloading autopage-0.5.0-py3-none-any.whl (29 kB)
# Collecting stevedore>=2.0.1
#   Downloading stevedore-3.5.0-py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 6.2 MB/s
# Collecting cmd2>=1.0.0
#   Downloading cmd2-2.4.0-py3-none-any.whl (150 kB)
#      |████████████████████████████████| 150 kB 58.4 MB/s
# Collecting pbr!=2.1.0,>=2.0.0
#   Downloading pbr-5.8.1-py2.py3-none-any.whl (113 kB)
#      |████████████████████████████████| 113 kB 37.3 MB/s
# Requirement already satisfied: attrs>=16.3.0 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (21.4.0)
# Requirement already satisfied: wcwidth>=0.1.7 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (0.2.5)
# Collecting pyperclip>=1.6
#   Downloading pyperclip-1.8.2.tar.gz (20 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->sqlalchemy>=1.1.0->optuna) (3.7.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.7/dist-packages (from Mako->alembic->optuna) (2.0.1)
# Building wheels for collected packages: pyperclip
#   Building wheel for pyperclip (setup.py) ... done
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11137 sha256=eaf6771c900f38ba60345fe59d032dfe119098d6f8bcaa1e2b6f99f8dd0b39d6
#   Stored in directory: /root/.cache/pip/wheels/9f/18/84/8f69f8b08169c7bae2dde6bd7daf0c19fca8c8e500ee620a28
# Successfully built pyperclip
# Installing collected packages: pyperclip, pbr, stevedore, Mako, cmd2, autopage, colorlog, cmaes, cliff, alembic, optuna
# Successfully installed Mako-1.1.6 alembic-1.7.6 autopage-0.5.0 cliff-3.10.1 cmaes-0.8.2 cmd2-2.4.0 colorlog-6.6.0 optuna-2.10.0 pbr-5.8.1 pyperclip-1.8.2 stevedore-3.5.0

# %%
import pandas as pd
import numpy as np
from xgboost import XGBClassifier
import optuna
from optuna import Trial, visualization
from optuna.samplers import TPESampler
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix, accuracy_score

# %%
import os, random # random seed 고정 
def set_seeds(seed): 
    os.environ['PYTHONHASHSEED'] = str(seed) 
    random.seed(seed) 
    np.random.seed(seed) 
    # tf.random.set_seed(seed) # Tensorflow 사용시 
    
SEED = 555
set_seeds(SEED)

# %%
train_fast = pd.read_csv('./train_fast_final.csv')
test_fast = pd.read_csv('./test_fast_final.csv')
train_slow = pd.read_csv('./train_slow_final.csv')
test_slow = pd.read_csv('./test_slow_final.csv')

# %%
train_fast.shape, test_fast.shape, train_slow.shape, test_slow.shape
# Out:
# ((102316, 68), (25575, 68), (102294, 68), (25575, 68))

# %%
X_fast_train = train_fast.drop(['fast_exist'], axis=1)
y_fast_train = train_fast.fast_exist

X_fast_test = test_fast.drop(['fast_exist'], axis=1)
y_fast_test = test_fast.fast_exist

# %%
X_slow_train = train_slow.drop(['slow_exist'], axis=1)
y_slow_train = train_slow.slow_exist

X_slow_test = test_slow.drop(['slow_exist'], axis=1)
y_slow_test = test_slow.slow_exist

# %% [markdown]
# ## non-selection

# %%
XGB = XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
              colsample_bynode=1, colsample_bytree=1, gamma=0,
              importance_type='gain', interaction_constraints='',
              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
              min_child_weight=1,
              n_estimators=100, n_jobs=-1, num_parallel_tree=1, random_state=42,
              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
              tree_method='exact', validate_parameters=1)

# %% [markdown]
# ### fast

# %%
XGB.fit(X_fast_train, y_fast_train)
y_fast_prob = XGB.predict_proba(X_fast_test)

for threshold in range(1,10):
    threshold = round(threshold*0.1, 1)
    y_fast_pred = np.where(y_fast_prob>=threshold, 1, 0)
    print(f'{threshold} :{f1_score(y_fast_test, y_fast_pred[:,1])}')
# Out:
# 0.1 :0.6086956521739131
# 0.2 :0.6885245901639344
# 0.3 :0.6909090909090909
# 0.4 :0.7037037037037037
# 0.5 :0.6923076923076923
# 0.6 :0.6666666666666666
# 0.7 :0.6956521739130435
# 0.8 :0.6666666666666665
# 0.9 :0.6666666666666665

# %% [markdown]
# ### slow

# %%
XGB.fit(X_slow_train, y_slow_train)
y_slow_prob = XGB.predict_proba(X_slow_test)

for threshold in range(1,10):
    threshold = round(threshold*0.1, 1)
    y_slow_pred = np.where(y_slow_prob>=threshold, 1, 0)
    print(f'{threshold} :{f1_score(y_slow_test, y_slow_pred[:,1])}')
# Out:
# 0.1 :0.6451612903225806
# 0.2 :0.6976744186046512
# 0.3 :0.6904761904761905
# 0.4 :0.7160493827160493
# 0.5 :0.7272727272727273
# 0.6 :0.767123287671233
# 0.7 :0.7714285714285714
# 0.8 :0.7575757575757577
# 0.9 :0.7419354838709677

# %% [markdown]
# ## tuning 후 feature selection (10~65)

# %%
ks = [10,15,20,25,30,35,40,45,50,55,60,65]

# %% [markdown]
# ### fast
# * 최적 score = 0.7777
# * 최적 k = 60
# * 최적 threshold = 0.4

# %%
fit = SelectKBest(chi2, k=45).fit(X_fast_train, y_fast_train)
new_X_fast_train = fit.transform(X_fast_train)
new_X_fast_test = fit.transform(X_fast_test)

XGB.fit(new_X_fast_train, y_fast_train)
y_fast_prob = XGB.predict_proba(new_X_fast_test)
print(f'================================{45}================================')
for threshold in range(1,10):
    threshold = round(threshold*0.1, 1)
    y_fast_pred = np.where(y_fast_prob>=threshold, 1, 0)
    print(f'{threshold} :{f1_score(y_fast_test, y_fast_pred[:,1])}')
# Out:
# ================================65================================
# 0.1 :0.6268656716417911
# 0.2 :0.6885245901639344
# 0.3 :0.7241379310344828
# 0.4 :0.7407407407407408
# 0.5 :0.7547169811320756
# 0.6 :0.7692307692307692
# 0.7 :0.6938775510204083
# 0.8 :0.6666666666666666
# 0.9 :0.6521739130434783

# %%
import joblib

# %%
pwd
# Out:
# '/content/drive/MyDrive/미니_프로젝트/data'

# %%
joblib.dump(XGB, '../model/fast_XGB_60k.pkl')
# Out:
# ['../model/fast_XGB_60k.pkl']

# %%
for k in ks:
    fit = SelectKBest(chi2, k=k).fit(X_fast_train, y_fast_train)
    new_X_fast_train = fit.transform(X_fast_train)
    new_X_fast_test = fit.transform(X_fast_test)
    
    XGB.fit(new_X_fast_train, y_fast_train)
    y_fast_prob = XGB.predict_proba(new_X_fast_test)
    print(f'================================{k}================================')
    for threshold in range(1,10):
        threshold = round(threshold*0.1, 1)
        y_fast_pred = np.where(y_fast_prob>=threshold, 1, 0)
        print(f'{threshold} :{f1_score(y_fast_test, y_fast_pred[:,1])}')
# Out:
# ================================10================================
# 0.1 :0.028530670470756067
# 0.2 :0.4044943820224719
# 0.3 :0.4473684210526316
# 0.4 :0.5074626865671642
# 0.5 :0.5614035087719298
# 0.6 :0.5454545454545454
# 0.7 :0.5454545454545454
# 0.8 :0.5714285714285714
# 0.9 :0.5957446808510639
# ================================15================================
# 0.1 :0.5121951219512195
# 0.2 :0.6176470588235294
# 0.3 :0.6774193548387097
# 0.4 :0.6428571428571428
# 0.5 :0.6296296296296295
# 0.6 :0.6
# 0.7 :0.6122448979591836
# 0.8 :0.5531914893617023
# 0.9 :0.5333333333333332
# ================================20================================
# 0.1 :0.5833333333333334
# 0.2 :0.6363636363636365
# 0.3 :0.6557377049180328
# 0.4 :0.6779661016949153
# 0.5 :0.7272727272727272
# 0.6 :0.6792452830188679
# 0.7 :0.72
# 0.8 :0.7083333333333334
# 0.9 :0.6363636363636364
# ================================25================================
# 0.1 :0.6551724137931034
# 0.2 :0.7169811320754718
# 0.3 :0.7307692307692308
# 0.4 :0.7058823529411765
# 0.5 :0.72
# 0.6 :0.72
# 0.7 :0.6938775510204083
# 0.8 :0.7083333333333334
# 0.9 :0.6818181818181819
# ================================30================================
# 0.1 :0.6333333333333332
# 0.2 :0.6909090909090909
# 0.3 :0.7169811320754718
# 0.4 :0.7169811320754718
# 0.5 :0.6923076923076923
# 0.6 :0.6530612244897959
# 0.7 :0.6382978723404256
# 0.8 :0.6511627906976745
# 0.9 :0.6190476190476191
# ================================35================================
# 0.1 :0.6268656716417911
# 0.2 :0.7241379310344828
# 0.3 :0.7547169811320756
# 0.4 :0.7307692307692308
# 0.5 :0.7058823529411765
# 0.6 :0.68
# 0.7 :0.68
# 0.8 :0.6938775510204083
# 0.9 :0.6521739130434783
# ================================40================================
# 0.1 :0.6268656716417911
# 0.2 :0.711864406779661
# 0.3 :0.711864406779661
# 0.4 :0.7017543859649122
# 0.5 :0.7407407407407408
# 0.6 :0.7307692307692308
# 0.7 :0.7450980392156863
# 0.8 :0.72
# 0.9 :0.72
# ================================45================================
# 0.1 :0.6268656716417911
# 0.2 :0.6885245901639344
# 0.3 :0.7241379310344828
# 0.4 :0.7407407407407408
# 0.5 :0.7547169811320756
# 0.6 :0.7692307692307692
# 0.7 :0.6938775510204083
# 0.8 :0.6666666666666666
# 0.9 :0.6521739130434783
# ================================50================================
# 0.1 :0.6666666666666667
# 0.2 :0.6774193548387097
# 0.3 :0.6774193548387097
# 0.4 :0.6785714285714285
# 0.5 :0.6666666666666666
# 0.6 :0.68
# 0.7 :0.68
# 0.8 :0.7083333333333334
# 0.9 :0.6808510638297872
# ================================55================================
# 0.1 :0.6268656716417911
# 0.2 :0.6885245901639344
# 0.3 :0.6779661016949153
# 0.4 :0.689655172413793
# 0.5 :0.7142857142857142
# 0.6 :0.7272727272727272
# 0.7 :0.72
# 0.8 :0.7346938775510204
# 0.9 :0.7083333333333334
# ================================60================================
# 0.1 :0.6562499999999999
# 0.2 :0.7000000000000001
# 0.3 :0.7241379310344828
# 0.4 :0.75
# 0.5 :0.7407407407407408
# 0.6 :0.6938775510204083
# 0.7 :0.6938775510204083
# 0.8 :0.6938775510204083
# 0.9 :0.6666666666666666
# ================================65================================
# 0.1 :0.6363636363636365
# 0.2 :0.6774193548387097
# 0.3 :0.736842105263158
# 0.4 :0.7636363636363636
# 0.5 :0.7450980392156863
# 0.6 :0.72
# 0.7 :0.72
# 0.8 :0.7083333333333334
# 0.9 :0.6808510638297872

# %% [markdown]
# ### slow
# * 최적 score = 0.7936
# * 최적 k = 65
# * 최적 threshold = 0.9

# %%
for k in ks:
    fit = SelectKBest(chi2, k=k).fit(X_slow_train, y_slow_train)
    new_X_slow_train = fit.transform(X_slow_train)
    new_X_slow_test = fit.transform(X_slow_test)
    
    XGB.fit(new_X_slow_train, y_slow_train)
    y_slow_prob = XGB.predict_proba(new_X_slow_test)
    print(f'================================{k}================================')
    for threshold in range(1,10):
        threshold = round(threshold*0.1, 1)
        y_slow_pred = np.where(y_slow_prob>=threshold, 1, 0)
        print(f'{threshold} :{f1_score(y_slow_test, y_slow_pred[:,1])}')
# Out:
# ================================10================================
# 0.1 :0.5769230769230769
# 0.2 :0.6741573033707865
# 0.3 :0.6419753086419753
# 0.4 :0.6493506493506493
# 0.5 :0.684931506849315
# 0.6 :0.676470588235294
# 0.7 :0.7076923076923077
# 0.8 :0.6984126984126984
# 0.9 :0.711864406779661
# ================================15================================
# 0.1 :0.6451612903225806
# 0.2 :0.7058823529411764
# 0.3 :0.725
# 0.4 :0.7272727272727273
# 0.5 :0.7297297297297297
# 0.6 :0.7323943661971831
# 0.7 :0.7352941176470588
# 0.8 :0.7384615384615385
# 0.9 :0.7096774193548386
# ================================20================================
# 0.1 :0.631578947368421
# 0.2 :0.6506024096385542
# 0.3 :0.6575342465753425
# 0.4 :0.6567164179104478
# 0.5 :0.65625
# 0.6 :0.6666666666666666
# 0.7 :0.7
# 0.8 :0.7
# 0.9 :0.711864406779661
# ================================25================================
# 0.1 :0.6741573033707865
# 0.2 :0.7012987012987012
# 0.3 :0.7105263157894737
# 0.4 :0.6933333333333332
# 0.5 :0.7323943661971831
# 0.6 :0.7761194029850748
# 0.7 :0.78125
# 0.8 :0.78125
# 0.9 :0.78125
# ================================30================================
# 0.1 :0.5436893203883495
# 0.2 :0.6292134831460674
# 0.3 :0.6190476190476191
# 0.4 :0.6419753086419753
# 0.5 :0.65
# 0.6 :0.6486486486486486
# 0.7 :0.6666666666666666
# 0.8 :0.6176470588235295
# 0.9 :0.6557377049180327
# ================================35================================
# 0.1 :0.5714285714285715
# 0.2 :0.6046511627906976
# 0.3 :0.6341463414634146
# 0.4 :0.6329113924050633
# 0.5 :0.6233766233766233
# 0.6 :0.6388888888888888
# 0.7 :0.6571428571428571
# 0.8 :0.676470588235294
# 0.9 :0.6349206349206349
# ================================40================================
# 0.1 :0.5660377358490566
# 0.2 :0.6304347826086957
# 0.3 :0.6666666666666667
# 0.4 :0.6829268292682926
# 0.5 :0.7088607594936709
# 0.6 :0.7105263157894737
# 0.7 :0.6857142857142857
# 0.8 :0.6666666666666667
# 0.9 :0.676470588235294
# ================================45================================
# 0.1 :0.6304347826086957
# 0.2 :0.6823529411764705
# 0.3 :0.6585365853658537
# 0.4 :0.6753246753246753
# 0.5 :0.6666666666666667
# 0.6 :0.6756756756756758
# 0.7 :0.6666666666666666
# 0.8 :0.676056338028169
# 0.9 :0.6567164179104478
# ================================50================================
# 0.1 :0.6060606060606061
# 0.2 :0.6904761904761905
# 0.3 :0.725
# 0.4 :0.7088607594936709
# 0.5 :0.7105263157894737
# 0.6 :0.7297297297297297
# 0.7 :0.6944444444444444
# 0.8 :0.7042253521126761
# 0.9 :0.676470588235294
# ================================55================================
# 0.1 :0.6041666666666667
# 0.2 :0.651685393258427
# 0.3 :0.6511627906976745
# 0.4 :0.7088607594936709
# 0.5 :0.7272727272727273
# 0.6 :0.7297297297297297
# 0.7 :0.7323943661971831
# 0.8 :0.7536231884057971
# 0.9 :0.7076923076923077
# ================================60================================
# 0.1 :0.6105263157894737
# 0.2 :0.6744186046511628
# 0.3 :0.7088607594936709
# 0.4 :0.7272727272727273
# 0.5 :0.7466666666666667
# 0.6 :0.7567567567567568
# 0.7 :0.7142857142857143
# 0.8 :0.676470588235294
# 0.9 :0.7076923076923077
# ================================65================================
# 0.1 :0.6666666666666666
# 0.2 :0.6987951807228916
# 0.3 :0.725
# 0.4 :0.7179487179487181
# 0.5 :0.7105263157894737
# 0.6 :0.7105263157894737
# 0.7 :0.7297297297297297
# 0.8 :0.7246376811594204
# 0.9 :0.746268656716418

# %%
fit = SelectKBest(chi2, k=25).fit(X_slow_train, y_slow_train)
new_X_slow_train = fit.transform(X_slow_train)
new_X_slow_test = fit.transform(X_slow_test)

XGB.fit(new_X_slow_train, y_slow_train)
y_slow_prob = XGB.predict_proba(new_X_slow_test)
print(f'================================{k}================================')
for threshold in range(1,10):
    threshold = round(threshold*0.1, 1)
    y_slow_pred = np.where(y_slow_prob>=threshold, 1, 0)
    print(f'{threshold} :{f1_score(y_slow_test, y_slow_pred[:,1])}')
# Out:
# ================================65================================
# 0.1 :0.6741573033707865
# 0.2 :0.7012987012987012
# 0.3 :0.7105263157894737
# 0.4 :0.6933333333333332
# 0.5 :0.7323943661971831
# 0.6 :0.7761194029850748
# 0.7 :0.78125
# 0.8 :0.78125
# 0.9 :0.78125

# %%
joblib.dump(XGB, '../model/slow_XGB_25k.pkl')
# Out:
# ['../model/slow_XGB_25k.pkl']

# %% [markdown]
# ## 기본 모델로 feature selection

# %%
XGB = XGBClassifier()

# %% [markdown]
# ## fast

# %%
for k in ks:
    fit = SelectKBest(chi2, k=k).fit(X_slow_train, y_slow_train)
    new_X_slow_train = fit.transform(X_slow_train)
    new_X_slow_test = fit.transform(X_slow_test)
    
    XGB.fit(new_X_slow_train, y_slow_train)
    y_slow_prob = XGB.predict_proba(new_X_slow_test)
    print(f'================================{k}================================')
    for threshold in range(1,10):
        threshold = round(threshold*0.1, 1)
        y_slow_pred = np.where(y_slow_prob>=threshold, 1, 0)
        print(f'{threshold} :{f1_score(y_slow_test, y_slow_pred[:,1])}')
# Out:
# ================================10================================
# 0.1 :0.09933774834437085
# 0.2 :0.12244897959183672
# 0.3 :0.1477832512315271
# 0.4 :0.16901408450704225
# 0.5 :0.1948051948051948
# 0.6 :0.21212121212121213
# 0.7 :0.23684210526315788
# 0.8 :0.27807486631016043
# 0.9 :0.3968253968253969
# ================================15================================
# 0.1 :0.11131725417439704
# 0.2 :0.1348314606741573
# 0.3 :0.15706806282722513
# 0.4 :0.18237082066869303
# 0.5 :0.2028985507246377
# 0.6 :0.24561403508771928
# 0.7 :0.288659793814433
# 0.8 :0.37241379310344824
# 0.9 :0.4444444444444445
# ================================20================================
# 0.1 :0.11049723756906078
# 0.2 :0.14218009478672988
# 0.3 :0.17341040462427745
# 0.4 :0.19999999999999998
# 0.5 :0.2426778242677824
# 0.6 :0.27999999999999997
# 0.7 :0.345679012345679
# 0.8 :0.3941605839416058
# 0.9 :0.5252525252525253
# ================================25================================
# 0.1 :0.11494252873563218
# 0.2 :0.15424164524421594
# 0.3 :0.18867924528301885
# 0.4 :0.22304832713754646
# 0.5 :0.25641025641025644
# 0.6 :0.3005181347150259
# 0.7 :0.31952662721893493
# 0.8 :0.41600000000000004
# 0.9 :0.5106382978723405
# ================================30================================
# 0.1 :0.11695906432748539
# 0.2 :0.145985401459854
# 0.3 :0.17804154302670622
# 0.4 :0.20863309352517986
# 0.5 :0.24786324786324782
# 0.6 :0.25641025641025644
# 0.7 :0.31788079470198677
# 0.8 :0.38095238095238093
# 0.9 :0.43137254901960786
# ================================35================================
# 0.1 :0.11904761904761907
# 0.2 :0.14814814814814814
# 0.3 :0.1834862385321101
# 0.4 :0.2028985507246377
# 0.5 :0.23236514522821577
# 0.6 :0.27979274611398963
# 0.7 :0.3225806451612903
# 0.8 :0.3968253968253969
# 0.9 :0.49019607843137253
# ================================40================================
# 0.1 :0.11787819253438114
# 0.2 :0.15463917525773194
# 0.3 :0.19543973941368079
# 0.4 :0.2172284644194757
# 0.5 :0.23788546255506607
# 0.6 :0.2934782608695652
# 0.7 :0.31901840490797545
# 0.8 :0.40310077519379856
# 0.9 :0.5208333333333334
# ================================45================================
# 0.1 :0.12170385395537528
# 0.2 :0.16666666666666669
# 0.3 :0.20905923344947736
# 0.4 :0.2426778242677824
# 0.5 :0.2801932367149758
# 0.6 :0.32222222222222224
# 0.7 :0.39455782312925164
# 0.8 :0.44799999999999995
# 0.9 :0.5054945054945054
# ================================50================================
# 0.1 :0.12371134020618557
# 0.2 :0.16348773841961856
# 0.3 :0.21276595744680848
# 0.4 :0.2532751091703057
# 0.5 :0.29896907216494845
# 0.6 :0.34523809523809523
# 0.7 :0.40845070422535207
# 0.8 :0.45000000000000007
# 0.9 :0.5054945054945054
# ================================55================================
# 0.1 :0.11278195488721805
# 0.2 :0.1380952380952381
# 0.3 :0.16811594202898553
# 0.4 :0.1993127147766323
# 0.5 :0.25
# 0.6 :0.28421052631578947
# 0.7 :0.35616438356164387
# 0.8 :0.40322580645161293
# 0.9 :0.5208333333333334
# ================================60================================
# 0.1 :0.11881188118811882
# 0.2 :0.1488833746898263
# 0.3 :0.18292682926829268
# 0.4 :0.2158273381294964
# 0.5 :0.2702702702702703
# 0.6 :0.3191489361702127
# 0.7 :0.36486486486486486
# 0.8 :0.4262295081967213
# 0.9 :0.43564356435643564
# ================================65================================
# 0.1 :0.1183431952662722
# 0.2 :0.15228426395939088
# 0.3 :0.18575851393188855
# 0.4 :0.22727272727272727
# 0.5 :0.2690582959641255
# 0.6 :0.3101604278074866
# 0.7 :0.3708609271523179
# 0.8 :0.4193548387096774
# 0.9 :0.5057471264367815

# %% [markdown]
# ## slow

# %%
for k in ks:
    fit = SelectKBest(chi2, k=k).fit(X_fast_train, y_fast_train)
    new_X_fast_train = fit.transform(X_fast_train)
    new_X_fast_test = fit.transform(X_fast_test)
    
    XGB.fit(new_X_fast_train, y_fast_train)
    y_fast_prob = XGB.predict_proba(new_X_fast_test)
    print(f'================================{k}================================')
    for threshold in range(1,10):
        threshold = round(threshold*0.1, 1)
        y_fast_pred = np.where(y_fast_prob>=threshold, 1, 0)
        print(f'{threshold} :{f1_score(y_fast_test, y_fast_pred[:,1])}')
# Out:
# ================================10================================
# 0.1 :0.01694915254237288
# 0.2 :0.03881700554528651
# 0.3 :0.05517241379310345
# 0.4 :0.06041335453100159
# 0.5 :0.0670391061452514
# 0.6 :0.08579088471849865
# 0.7 :0.11494252873563218
# 0.8 :0.1346153846153846
# 0.9 :0.2696629213483146
# ================================15================================
# 0.1 :0.05234460196292258
# 0.2 :0.07603305785123966
# 0.3 :0.09954751131221719
# 0.4 :0.10644257703081232
# 0.5 :0.13620071684587814
# 0.6 :0.16521739130434782
# 0.7 :0.2
# 0.8 :0.26277372262773724
# 0.9 :0.36363636363636365
# ================================20================================
# 0.1 :0.05700123915737299
# 0.2 :0.07299270072992702
# 0.3 :0.0970873786407767
# 0.4 :0.1162079510703364
# 0.5 :0.14400000000000002
# 0.6 :0.18947368421052632
# 0.7 :0.2411347517730496
# 0.8 :0.3300970873786408
# 0.9 :0.3947368421052632
# ================================25================================
# 0.1 :0.09341825902335456
# 0.2 :0.1301775147928994
# 0.3 :0.16666666666666669
# 0.4 :0.22448979591836732
# 0.5 :0.2763157894736842
# 0.6 :0.27692307692307694
# 0.7 :0.3185840707964602
# 0.8 :0.3655913978494624
# 0.9 :0.4788732394366197
# ================================30================================
# 0.1 :0.09565217391304348
# 0.2 :0.13749999999999998
# 0.3 :0.19047619047619047
# 0.4 :0.25142857142857145
# 0.5 :0.2837837837837838
# 0.6 :0.304
# 0.7 :0.3486238532110092
# 0.8 :0.4137931034482759
# 0.9 :0.4411764705882353
# ================================35================================
# 0.1 :0.10900473933649289
# 0.2 :0.14388489208633096
# 0.3 :0.1932367149758454
# 0.4 :0.2285714285714286
# 0.5 :0.3007518796992481
# 0.6 :0.3448275862068966
# 0.7 :0.3653846153846154
# 0.8 :0.4691358024691359
# 0.9 :0.43478260869565216
# ================================40================================
# 0.1 :0.11401425178147269
# 0.2 :0.14583333333333331
# 0.3 :0.20100502512562812
# 0.4 :0.25477707006369427
# 0.5 :0.31007751937984496
# 0.6 :0.35398230088495575
# 0.7 :0.38297872340425526
# 0.8 :0.4556962025316456
# 0.9 :0.4705882352941177
# ================================45================================
# 0.1 :0.11499999999999999
# 0.2 :0.15384615384615383
# 0.3 :0.18779342723004697
# 0.4 :0.2484472049689441
# 0.5 :0.3125
# 0.6 :0.36036036036036034
# 0.7 :0.3789473684210526
# 0.8 :0.44155844155844154
# 0.9 :0.5230769230769231
# ================================50================================
# 0.1 :0.12432432432432433
# 0.2 :0.17557251908396945
# 0.3 :0.23834196891191714
# 0.4 :0.267515923566879
# 0.5 :0.3065693430656935
# 0.6 :0.347107438016529
# 0.7 :0.3883495145631068
# 0.8 :0.4470588235294118
# 0.9 :0.4594594594594595
# ================================55================================
# 0.1 :0.12121212121212122
# 0.2 :0.1672727272727273
# 0.3 :0.2028985507246377
# 0.4 :0.2545454545454546
# 0.5 :0.3021582733812949
# 0.6 :0.3652173913043479
# 0.7 :0.40425531914893614
# 0.8 :0.43902439024390244
# 0.9 :0.4788732394366197
# ================================60================================
# 0.1 :0.1266490765171504
# 0.2 :0.1722846441947566
# 0.3 :0.2153846153846154
# 0.4 :0.24999999999999997
# 0.5 :0.29166666666666674
# 0.6 :0.347107438016529
# 0.7 :0.39999999999999997
# 0.8 :0.47191011235955066
# 0.9 :0.463768115942029
# ================================65================================
# 0.1 :0.13370473537604458
# 0.2 :0.18253968253968256
# 0.3 :0.22702702702702704
# 0.4 :0.2837837837837838
# 0.5 :0.3230769230769231
# 0.6 :0.3684210526315789
# 0.7 :0.4329896907216495
# 0.8 :0.45454545454545453
# 0.9 :0.4736842105263158
